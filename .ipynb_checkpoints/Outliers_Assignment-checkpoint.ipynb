# %% [markdown]
# ### Import your librares

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load your dataset

# %%
data = pd.read_csv("seattle_weather.csv")
data
# Out:
#              DATE  PRCP  TMAX  TMIN   RAIN
# 0      1948-01-01  0.47    51    42   True
# 1      1948-01-02  0.59    45    36   True
# 2      1948-01-03  0.42    45    35   True
# 3      1948-01-04  0.31    45    34   True
# 4      1948-01-05  0.17    45    32   True
# ...           ...   ...   ...   ...    ...
# 25546  2017-12-10  0.00    49    34  False
# 25547  2017-12-11  0.00    49    29  False
# 25548  2017-12-12  0.00    46    32  False
# 25549  2017-12-13  0.00    48    34  False
# 25550  2017-12-14  0.00    50    36  False
#
# [25551 rows x 5 columns]

# %%
data.dtypes
# Out:
# DATE     object
# PRCP    float64
# TMAX      int64
# TMIN      int64
# RAIN     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25551 entries, 0 to 25550
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    25551 non-null  object
#  1   PRCP    25548 non-null  float64
#  2   TMAX    25551 non-null  int64
#  3   TMIN    25551 non-null  int64
#  4   RAIN    25548 non-null  object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 998.2+ KB

# %% [markdown]
# ### Repeat the following steps for each column within outliers
#
# * Visualize the outliers
# * Detect if your data set contains any outliers
# * Identify lower & higher limit of outliers
# * Drop all outliers
# * Visualize the column after processing

# %%
data['RAIN'].value_counts()
# Out:
# RAIN
# False    14648
# True     10900
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#                PRCP          TMAX          TMIN
# count  25548.000000  25551.000000  25551.000000
# mean       0.106222     59.544206     44.514226
# std        0.239031     12.772984      8.892836
# min        0.000000      4.000000      0.000000
# 25%        0.000000     50.000000     38.000000
# 50%        0.000000     58.000000     45.000000
# 75%        0.100000     69.000000     52.000000
# max        5.020000    103.000000     71.000000

# %% [markdown]
# 1. PRCP have a max of 5 and mean of 0.1, std of 0.2 meaning there is outliers
# 2. TMAX also have outliers as mean 25%, 50%, 75% are close to each other, but the max is far away with 103

# %%
import plotly.express as px
import seaborn as sns

# %%
sns.pairplot(data[['PRCP', 'TMAX', 'TMIN']])

# %% [markdown]
# there is a clear positive and strong relation between Tmin and Tmax, with some outliers
# Tmax surely have outliers

# %%
sns.boxplot(data)
# Out:
# <Axes: >

# %%
def limits(col):
    Q1 = col.quantile(0.25)
    Q3 = col.quantile(0.75)
    IQR = Q3 - Q1

    upper = Q3 + 1.5*IQR
    lower = Q1 - 1.5*IQR

    print("Upper Bound:",upper)   
    print("Lower Bound:",lower)
    return upper, lower
    
    
print("PRCP")
PRCPupper, PRCPlower = limits(data['PRCP'])
print("--------------------")
print("TMAX")
TMAXupper, TMAXlower = limits(data['TMAX'])
print("--------------------")
print("TMIN")
TMINupper, TMINlower = limits(data['TMIN'])
# Out:
# PRCP
# Upper Bound: 0.25
# Lower Bound: -0.15000000000000002
# --------------------
# TMAX
# Upper Bound: 97.5
# Lower Bound: 21.5
# --------------------
# TMIN
# Upper Bound: 73.0
# Lower Bound: 17.0

# %%
#droping the outliers the 
outliers = data[(data['PRCP'] < PRCPlower) | (data['PRCP'] > PRCPupper)]
data = data.drop(outliers.index)

outliers = data[(data['TMAX'] < TMAXlower) | (data['TMAX'] > TMAXupper)]
data = data.drop(outliers.index)

outliers = data[(data['TMIN'] < TMINlower) | (data['TMIN'] > TMINupper)]
data = data.drop(outliers.index)

# %%
data
# Out:
#              DATE  PRCP  TMAX  TMIN   RAIN
# 4      1948-01-05  0.17    45    32   True
# 7      1948-01-08  0.04    48    35   True
# 8      1948-01-09  0.12    50    31   True
# 10     1948-01-11  0.01    42    32   True
# 11     1948-01-12  0.00    41    26  False
# ...           ...   ...   ...   ...    ...
# 25546  2017-12-10  0.00    49    34  False
# 25547  2017-12-11  0.00    49    29  False
# 25548  2017-12-12  0.00    46    32  False
# 25549  2017-12-13  0.00    48    34  False
# 25550  2017-12-14  0.00    50    36  False
#
# [21893 rows x 5 columns]

# %%
sns.boxplot(data)
# Out:
# <Axes: >

# %%
sns.pairplot(data[['PRCP', 'TMAX', 'TMIN']])
